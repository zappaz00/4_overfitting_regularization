# %% [markdown]
# # Overfitting and Regularization

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tqdm
# import warnings
# warnings.filterwarnings('ignore')

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn import set_config

# %%
set_config(display='diagram')

# %% [markdown]
# ## Settings

# %%
SEED = 42
RANGE = (-5, 5)
N_SAMPLES = 50
DEGREES = np.linspace(0, 15, 1 + 15, dtype=int)
ALPHAS = np.linspace(0, 0.5, 1 + 40)

# %% [markdown]
# ## Part 1: Underfitting vs. overfitting

# %% [markdown]
# ### Generate samples

# %% [markdown]
# Let's pick a target function $ f(x) = 2\cdot x + 10\cdot sin(x) $ and generate some noisy samples to learn from.

# %%
def target_function(x):
    return 2 * x + 10 * np.sin(x)

def generate_samples():
    """Generate noisy samples."""
    np.random.seed(SEED)
    x = np.random.uniform(*RANGE, size=N_SAMPLES)
    y = target_function(x) + np.random.normal(scale=4, size=N_SAMPLES)
    return x.reshape(-1, 1), y

X, y = generate_samples()

# %% [markdown]
# ### Plot samples

# %%
def plot_scatter(x, y, title=None, label='Noisy samples'):
    plt.scatter(x, y, label=label)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.title(title)
    plt.legend(loc='lower right')

plot_scatter(X, y)

# %% [markdown]
# ### Split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=SEED)

plot_scatter(X_train, y_train, label='Training set')
plot_scatter(X_valid, y_valid, label='Validation set')

# %%
y_train
# Out:
# array([ -1.10771616,   0.84986647,  -9.62110024,   3.70972424,
#         -2.36319095,   5.83708039, -16.53330524,  -1.8815588 ,
#        -11.1506254 ,   1.0883081 ,  -9.05957818, -14.72254274,
#          5.71746212,   5.48508317,  -6.81897956,  -1.80751907,
#         -2.14124891, -12.83476672,  -0.09034969,  -3.48222266,
#         11.50001273,  -2.03019037,  10.03142993, -17.18409407,
#         -2.48182149,   1.67461593, -17.32081894,  -6.32825039,
#         -4.15121484,   9.31494651,   6.5817456 ,   6.58351686,
#         -1.83803375,  11.27589865,  13.68530977])

# %% [markdown]
# ### Model

# %% [markdown]
# Let's try to approximate our target function $ f(x) = 2\cdot x + 10\cdot sin(x) $ with polynomials of different degree.
#
# A polynomial of degree $n$ has the form:
# $ h(x) = w_0 + w_1\cdot x + w_2\cdot x^2 +\ldots + w_n\cdot x^n $.
#
# $x^i$ values could easily be generated by `PolynomialFeatures`, while $w_i$ are the unknown paramaters to be estimated using `LinearRegression`.

# %%
PolynomialFeatures(degree=4, include_bias=False).fit_transform(X=[
    [1],
    [3],
    [4],
])
# Out:
# array([[  1.,   1.,   1.,   1.],
#        [  3.,   9.,  27.,  81.],
#        [  4.,  16.,  64., 256.]])

# %%
def make_model(degree, alpha=0, penalty=None):
    # linear regression
    if alpha == 0:
        regressor = LinearRegression()
    # lasso regression",
    elif penalty == 'L1':
        regressor = Lasso(alpha=alpha, random_state=SEED, max_iter=50000)
    # ridge regression",
    elif penalty == 'L2':
        regressor = Ridge(alpha=alpha, random_state=SEED, max_iter=50000) 
    
    
    return Pipeline([
        ('pol', PolynomialFeatures(degree, include_bias=(degree == 0))),
        ('sca', StandardScaler()),
        ('reg', regressor)
    ])

display(make_model(2))
display(make_model(2, penalty='L1', alpha=0.1))
display(make_model(2, penalty='L2', alpha=0.1))
# Out:
# Pipeline(steps=[('pol', PolynomialFeatures(include_bias=False)),
#                 ('sca', StandardScaler()), ('reg', LinearRegression())])
# Pipeline(steps=[('pol', PolynomialFeatures(include_bias=False)),
#                 ('sca', StandardScaler()),
#                 ('reg', Lasso(alpha=0.1, max_iter=50000, random_state=42))])
# Pipeline(steps=[('pol', PolynomialFeatures(include_bias=False)),
#                 ('sca', StandardScaler()),
#                 ('reg', Ridge(alpha=0.1, max_iter=50000, random_state=42))])

# %% [markdown]
# ### Fit

# %% [markdown]
# Let's fit a model and plot the hypothesis it learns:

# %%
def plot_fit(model):
    degree = model['pol'].degree
    X_range = np.linspace(*RANGE, 1000).reshape(-1, 1)
    y_pred = model.predict(X_range)
    plot_scatter(X_train, y_train, label='Training sample')
    plot_scatter(X_valid, y_valid, label='Validation sample')
    plt.plot(X_range, target_function(X_range), c='green', alpha=0.2, lw=5, label='Target function')
    plt.plot(X_range, y_pred, c='red', label='Hypothesis')
    plt.ylim((min(y) - 3, max(y) + 3))
    plt.legend(loc='best')    
    plt.title(f'Polynomial approximation: degree={degree}')
    plt.show()

plot_fit(make_model(degree=2).fit(X_train, y_train))

# %% [markdown]
# ### From underfitting to overfitting

# %% [markdown]
# We can investigate the shape of the fitted curve for different values of `degree`:

# %%
for degree in [0, 1, 2, 3, 4, 5, 10, 15, 20]:
    plot_fit(make_model(degree).fit(X_train, y_train))

# %% [markdown]
# ### Fitting graph

# %% [markdown]
# In the next step we calculate the training and the validation error for each `degree` and plot them in a single graph. The resulting graph is called the fitting graph.

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def plot_fitting_graph(x, metric_train, metric_valid, xlabel, ylabel, 
                       custom_metric=None, custom_label='', custom_scale='log', title='Fitting graph'):
    plt.figure(figsize=(9, 4.5))
    plt.plot(x, metric_train, label='Training')
    plt.plot(x, metric_valid, color='C1', label='Validation')
    plt.axvline(x[np.argmin(metric_valid)], color='C1', lw=10, alpha=0.2)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.xticks(x, rotation='vertical')
    plt.legend(loc='center left')        
    if custom_metric:
        plt.twinx()
        plt.yscale(custom_scale)
        plt.plot(x, custom_metric, alpha=0.2, lw=4, ls='dotted', color='black', label=custom_label) 
        plt.legend(loc='center right')         
    plt.show()
    
rmse_train, rmse_valid = [], []
for degree in DEGREES:
    reg = make_model(degree).fit(X_train, y_train)
    rmse_train.append(rmse(reg.predict(X_train), y_train))
    rmse_valid.append(rmse(reg.predict(X_valid), y_valid))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)', 
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Sweet spot

# %% [markdown]
# What is the optimal `degree` to go with?

# %%
DEGREES[np.argmin(rmse_valid)]
# Out:
# 5

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# Ideally, we would choose the the model parameters such that we have the best model performance. However, we want to make sure that we really have the best validation performance. When we do `train_test_split` we randomly split the data into two parts. What could happen is that we got lucky and split the data such that it favours the validation error. This is especially dangerous if we are dealing with small datasets. One way to check if that's the case is to run the experiment several times for different, random splits. However, there is an even more systematic way of doing this: [cross-validation](https://scikit-learn.org/stable/modules/cross_validation.html).

# %% [markdown]
# <img src="https://scikit-learn.org/stable/_images/grid_search_cross_validation.png" width=50% />

# %%
rmse_train, rmse_valid = [], []
for degree in DEGREES:
    results = cross_validate(make_model(degree), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Model coefficients

# %% [markdown]
# Let's inspect our regression model coefficients:

# %%
(make_model(degree=1).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=2).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=5).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=10).fit(X_train, y_train)['reg'].coef_)
# Out:
# (array([2.81292778]),
#  array([2.80049884, 0.45166501]),
#  array([ 30.87315584,   1.48752361, -54.60227825,  -1.63699842,
#          26.62792933]),
#  array([  33.63850705,  -41.86346242,  -70.48743112,  278.98853452,
#           27.48125634, -656.36383501,   59.32988346,  651.64795186,
#          -47.55728814, -233.48455138]))

# %% [markdown]
# Hmm... it looks like high degree polynomials are coming with much bigger regression coefficients.
#
# We are going to plot the mean absolute value of $w_i$ as a function of degree to reveal the relationship:

# %%
rmse_train, rmse_valid, avg_coef = [], [], []
for degree in DEGREES:
    results = cross_validate(make_model(degree),
                             X, y, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))        
    avg_coef.append(        
        # average over CV folds
        np.mean([            
            # mean absolute value of weights
            np.mean(np.abs(model['reg'].coef_))
            for model in results['estimator']
        ]))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid,
                   xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   custom_metric=avg_coef, custom_label='avg(|$w_i$|)',
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Summary

# %% [markdown]
# We observe the following:
#
# 1. **Underfitting** (degree < 5): The model is not able to fit the data properly. The fit is bad for both the training and the validation set.
#
# 2. **Fit is just right** (degree = 5): The model is able to capture the underlying data distribution. The fit is good for both the training and the validation set.
#
# 3. **Overfitting** (degree > 5): The model starts fitting the noise in the dataset. While the fit for the training data gets even better, the fit for the validation set gets worse.
#
# 4. As the order of polynomial increases, the linear model coefficients become more likely to take on **large values**.

# %% [markdown]
# ## Part 2: Regularization

# %% [markdown]
# There are two major ways to build a machine learning model with the ability to generalize well on unseen data:
# 1. Train the simplest model possible for our purpose (according to Occam’s Razor).
# 2. Train a complex or more expressive model on the data and perform regularization.
#
# Regularization is a method used to reduce the variance of a machine learning model. In other words, it is used to reduce overfitting. Regularization penalizes a model for being complex. For linear models, it means regularization forces model coefficients to be smaller in magnitude.
#
# Let's pick a polynomial model of degree **15** (which tends to overfit strongly) and try to regularize it using **L1** and **L2** penalties.

# %% [markdown]
# ### L1 - Lasso regression

# %%
rmse_train, rmse_valid = [], []
for alpha in ALPHAS:    
    results = cross_validate(make_model(degree=15, penalty='L1', alpha=alpha), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid,
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)',
                   title='Lasso polynomial regression (L1): degree=15')

# %% [markdown]
# ### L2 - Ridge regression

# %%
rmse_train, rmse_valid = [], []
for alpha in ALPHAS:    
    results = cross_validate(make_model(degree=15, penalty='L2', alpha=alpha), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid, 
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)', 
                   title='Ridge polynomial regression (L2): degree=15')

# %% [markdown]
# ### Summary

# %% [markdown]
# 1. We can control the regularization strength by changing the hyperparameter `alpha`.
# 2. Regularized version of the model performs pretty well. Even in case the original original (unregularized) model is heavily overfitting due to excessive complexity.

# %% [markdown]
# ## Part 3: Homework assignment (10 points)

# %% [markdown]
# ### Excercise 1 - Overfiting and Underfitting (2 points)

# %% [markdown]
# Let's work with the diabetes dataset

# %%
from sklearn.datasets import load_diabetes
data = load_diabetes()
X_diabetes = pd.DataFrame(data['data'], columns=data['feature_names'])
y_diabetes = pd.DataFrame(data['target'], columns=['target'])
print(data['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %% [markdown]
# Apply model for diabetes dataset with polynomial feature engineering of different degrees. Plot the dependence of train and test error on polynomial degree. Highlight a degree with the best test error. Which degrees cause overfitting/underfitting? Why?

# %% [markdown]
# # Сначала посмотрим на сами данные и отрисуем их связь с целевой переменной

# %%
X_diabetes
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
X_diabetes.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.639623e-16  1.309912e-16 -8.013951e-16  1.289818e-16 -9.042540e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.301121e-16 -4.563971e-16  3.863174e-16 -3.848103e-16 -3.398488e-16
# ...

# %%
X_diabetes.isna().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %% [markdown]
# Пропущенных данных нет

# %%
fig, axs = plt.subplots(2, 5, figsize=(20, 10))
plt_ctr = 0

for col in X_diabetes.columns.values:
    plt_y_ctr = int(plt_ctr % 5)
    plt_x_ctr = int(plt_ctr / 5)
    
    axs[plt_x_ctr, plt_y_ctr].scatter(X_diabetes[col], y_diabetes, label='Training')
    axs[plt_x_ctr, plt_y_ctr].grid(True)
    axs[plt_x_ctr, plt_y_ctr].legend(loc='lower right')
    axs[plt_x_ctr, plt_y_ctr].set_title(col)
    
    plt_ctr += 1

# %% [markdown]
# У некоторых признаков видна линейная зависимость - bmi, bp, s1, s2, s3, s5, s6. Но она с большой дисперсией. По sex, age, s4 зависимость прям так себе.

# %%
sns.heatmap(pd.concat([X_diabetes, y_diabetes], axis=1).corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Попробуем применить обучение регрессии

# %% [markdown]
# При построении модели оставила масштабирование, хоть признаки и отмасштабированы изначально. В основном из-за того, что после взятия степени всё может поехать и перемножения признаков между собой. Уменьшила количество записей и порезала тип данных до float32, чтоб хоть как-то это всё посчиталось. В целом при переходе от float64 к float32 ничего особо не изменилось, так что норм. Нам не нужна гигантическая точность тут.
# Также из-за вычислительной сложности степени будем вычислять не для всех признаков (это было рекомендацией администратора в ветке обсуждений). Один из способов уменьшить количество признаков - это не прогонять часть через PolynomialFeatures, а оставить как есть. Для этого есть ColumnTransformer. В PolynomialFeatures прокинула только довольно нелинейный s4, прокидывание остальных приводит к очень большому переобучению на некоторых степенях и из-за этого на графике не видно нормальные степени. Оставила один признак - это ошибкой не считается.

# %%
def make_model(degree, alpha=0, penalty=None):
    # linear regression
    if alpha == 0:
        regressor = LinearRegression()
    # lasso regression",
    elif penalty == 'L1':
        regressor = Lasso(alpha=alpha, random_state=SEED, max_iter=500000)
    # ridge regression",
    elif penalty == 'L2':
        regressor = Ridge(alpha=alpha, random_state=SEED, max_iter=50000) 
    
    clmn_trnsfrmr = ColumnTransformer([
    ('clmn_pass', 'passthrough', ['sex', 'age', 'bmi', 'bp', 's1', 's2', 's3', 's5', 's6']),
    ('clmn_poly', PolynomialFeatures(degree, include_bias=(degree == 0)), ['s4'])
    ])
    
    return Pipeline([
        ('pol', clmn_trnsfrmr),
        # ('pol', PolynomialFeatures(degree, include_bias=(degree == 0))),
        ('sca', StandardScaler()),
        ('reg', regressor)
    ])

display(make_model(2))
# Out:
# Pipeline(steps=[('pol',
#                  ColumnTransformer(transformers=[('clmn_pass', 'passthrough',
#                                                   ['sex', 'age', 'bmi', 'bp',
#                                                    's1', 's2', 's3', 's5',
#                                                    's6']),
#                                                  ('clmn_poly',
#                                                   PolynomialFeatures(include_bias=False),
#                                                   ['s4'])])),
#                 ('sca', StandardScaler()), ('reg', LinearRegression())])

# %%
DEGREES_without_zero = []
for degree in DEGREES:
    if degree != 0: #баг в PolynomialFeatures - не вычисляет нулевую степень для множества колонок.
        DEGREES_without_zero.append(degree)

# %%
rmse_train, rmse_valid, avg_coef = [], [], []

for deg in tqdm.tqdm(DEGREES_without_zero): 
    results = cross_validate(make_model(deg),
                             X_diabetes, y_diabetes, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score'])) 
    
    avg_coef.append(        
    # average over CV folds
    np.mean([            
        # mean absolute value of weights
        np.mean(np.abs(model['reg'].coef_))
        for model in results['estimator']
    ]))
    
plot_fitting_graph(DEGREES_without_zero, rmse_train, rmse_valid,
                   xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   custom_metric=avg_coef, custom_label='avg(|$w_i$|)',
                   title='Least squares polynomial regression')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 15.64it/s]

# %%
DEGREES_without_zero[np.argmin(rmse_valid)]
# Out:
# 1

# %% [markdown]
# * Для валидационного набора лучшая степень полинома - первая. Видимо потому что на графиках выше было видно, что многие признаки линейно-зависимы.
# * На графике выше также отображён средний модуль коэффициентов модели. Чем больше степень, тем выше средний модуль весов - указывает на переобучение.

# %% [markdown]
# ### Excercise 2 - Magnitude (3 points)

# %% [markdown]
# As discussed earlier, regularization methods are expected to constraint the weights (model coefficients).
#
# Is it indeed happening?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**). Let's use `degree=15` and `alpha` from `ALPHAS`.

# %% [markdown]
# #### L1

# %%
all_coefs_l1 = {} #Будем хитрыми и запомним коэффициенты для следующего задания, а то пересчитывать это - жесть
rmse_train = []
rmse_valid = []
avg_coef = []

coef_ctr = 0
degree = 15
for alpha in tqdm.tqdm(ALPHAS):
    model = make_model(degree, penalty='L1', alpha=alpha)
    
    results = cross_validate(model,
                             X_diabetes, y_diabetes, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score'])) 
    avg_coef.append(        
    # average over CV folds
    np.mean([            
        # mean absolute value of weights
        np.mean(np.abs(model['reg'].coef_))
        for model in results['estimator']
    ]))
    
    best_coeffs_indx = np.argmin([
        np.mean(np.abs(model['reg'].coef_))
        for model in results['estimator']
    ])
    all_coefs_l1[coef_ctr] = results['estimator'][best_coeffs_indx]['reg'].coef_
    coef_ctr += 1
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid,
                   xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   custom_metric=avg_coef, custom_label='avg(|$w_i$|)',
                   title='Lasso polynomial regression')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 41/41 [00:03<00:00, 12.04it/s]

# %% [markdown]
# #### L2

# %%
all_coefs_l2 = {} #Будем хитрыми и запомним коэффициенты для следующего задания, а то пересчитывать это - жесть
rmse_train = []
rmse_valid = []
avg_coef = []

coef_ctr = 0
degree = 15
for alpha in tqdm.tqdm(ALPHAS):
    model = make_model(degree, penalty='L2', alpha=alpha)

    results = cross_validate(model,
                             X_diabetes, y_diabetes, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score'])) 
    
    avg_coef.append(        
    # average over CV folds
    np.mean([            
        # mean absolute value of weights
        np.mean(np.abs(model['reg'].coef_))
        for model in results['estimator']
    ]))
    
    best_coeffs_indx = np.argmin([
        np.mean(np.abs(model['reg'].coef_))
        for model in results['estimator']
    ])
    all_coefs_l2[coef_ctr] = results['estimator'][best_coeffs_indx]['reg'].coef_
    coef_ctr += 1
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid,
                   xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   custom_metric=avg_coef, custom_label='avg(|$w_i$|)',
                   title='Ridge polynomial regression')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 41/41 [00:02<00:00, 17.90it/s]

# %% [markdown]
# #### Summary

# %% [markdown]
# Действительно видим на графиках выше, что средний модуль коэффициентов модели на разных степенях стал значительно ниже, чем без регуляризации (серая пунктирная линия). Без регуляризации средний модуль приближался к 10^7, а с регуляризацией обоих видов он меньше 10. Также снизилась ошибка на валидационном датасете для всех степеней - это означает, что регуляризация помогла победить переобучение.

# %% [markdown]
# ### Excercise 3 - Sparsity (3 points)

# %% [markdown]
# Lasso can also be used for **feature selection** since L1 is [more likely to produce zero coefficients](https://explained.ai/regularization/).
#
# Is it indeed happening?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**). Let's use `degree=15` and `alpha` from `ALPHAS`.

# %% [markdown]
# #### L1

# %%
coef_ctr = 0
zero_counts = []

for alpha in ALPHAS:
    zero_counts.append(1.0 - np.count_nonzero(all_coefs_l1[coef_ctr]) / all_coefs_l1[coef_ctr].size)
    coef_ctr+=1
    
plt.plot(ALPHAS, zero_counts, label=alpha)
plt.ylabel('zero share')
plt.xlabel('alpha')
plt.title('L1 zero coeffs share')
# Out:
# Text(0.5, 1.0, 'L1 zero coeffs share')

# %% [markdown]
# #### L2

# %% [markdown]
# Во время обечения возникали предупреждения: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead. Как написано в одной из issue на гитхабе это означает, что количество признаков очень сильно превышает размерность данных. В результате такого обучения alpha почти не влияла на результат - коэффициенты практически равны.

# %%
coef_ctr = 0
zero_counts = []

for alpha in ALPHAS:
    zero_counts.append(1.0 - np.count_nonzero(all_coefs_l2[coef_ctr]) / all_coefs_l2[coef_ctr].size)
    coef_ctr+=1
    
plt.plot(ALPHAS, zero_counts, label=alpha)
plt.ylabel('zero share')
plt.xlabel('alpha')
plt.title('L2 zero coeffs share')
# Out:
# Text(0.5, 1.0, 'L2 zero coeffs share')

# %% [markdown]
# #### Summary

# %% [markdown]
# * Для L1 видим, что доля нулевых коэффициентов растёт по мере увеличения параметра alpha. Для alpha=0.5 доля нулевых коэффициентов - почти 60%.
# * Для L2 ни при каких alpha коэффициенты не обращаются в абсолютный ноль, что в целом ожидаемо в силу того, что минимизируем сумму квадратов.
#
# Обе нормы ведут себя предсказуемо

# %% [markdown]
# ### Excercise 4 - Scaling (2 points)

# %% [markdown]
# As a general rule, it is recommended to scale input features before fitting a regularized model so that the features/inputs take values in similar ranges. One common way of doing so is to standardize the inputs and that is exactly what our pipeline  second step (`StandardScaler`) is responsible for.
#
# Is scaling important? What are the underlying reasons?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**) on the dataset below. Check coefficients.

# %%
def target_function_hw(x):
    return 2 * x

def generate_samples_hw():
    np.random.seed(SEED)
    x = np.random.uniform(*RANGE, size=N_SAMPLES)
    
    np.random.seed(SEED+1)
    x_noise = np.random.uniform(*[x * 100 for x in RANGE], size=N_SAMPLES)
    x_noise2 = np.random.normal(100, 50, size=N_SAMPLES)
    
    y = target_function_hw(x) + np.random.normal(scale=4, size=N_SAMPLES)
    
    return np.concatenate([x.reshape(-1, 1) / 100, 
                           x_noise.reshape(-1, 1),
                           x_noise2.reshape(-1, 1)], axis=1), y

X_hw, y_hw = generate_samples_hw()

for i in range(X_hw.shape[1]):
    print(f'Min of feature {i}: {min(X_hw[:, i]):.2f}, max: {max(X_hw[:, i]):.2f}')
# Out:
# Min of feature 0: -0.05, max: 0.05
# Min of feature 1: -494.87, max: 493.57
# Min of feature 2: -2.35, max: 213.31

# %% [markdown]
# В задании ни слова про полиномы - убираем их из модели и создаём флаг - нужно ли масштабировать. В целом таргет функция 100% линейная и в полиномах смысла нет.

# %%
def make_model(alpha=0, penalty=None, is_scale=False):
    # linear regression
    if alpha == 0:
        regressor = LinearRegression()
    # lasso regression",
    elif penalty == 'L1':
        regressor = Lasso(alpha=alpha, random_state=SEED, max_iter=50000)
    # ridge regression",
    elif penalty == 'L2':
        regressor = Ridge(alpha=alpha, random_state=SEED, max_iter=50000) 
    
    if is_scale:
        return Pipeline([
        ('sca', StandardScaler()),
        ('reg', regressor)
        ])
    else:
        return Pipeline([
        ('reg', regressor)
        ])
    
display(make_model(alpha=0, is_scale=False))
display(make_model(alpha=0, is_scale=True))
display(make_model(alpha=0.1, penalty='L1', is_scale=False))
display(make_model(alpha=0.1, penalty='L1', is_scale=True))
display(make_model(alpha=0.1, penalty='L2', is_scale=False))
display(make_model(alpha=0.1, penalty='L2', is_scale=True))
# Out:
# Pipeline(steps=[('reg', LinearRegression())])
# Pipeline(steps=[('sca', StandardScaler()), ('reg', LinearRegression())])
# Pipeline(steps=[('reg', Lasso(alpha=0.1, max_iter=50000, random_state=42))])
# Pipeline(steps=[('sca', StandardScaler()),
#                 ('reg', Lasso(alpha=0.1, max_iter=50000, random_state=42))])
# Pipeline(steps=[('reg', Ridge(alpha=0.1, max_iter=50000, random_state=42))])
# Pipeline(steps=[('sca', StandardScaler()),
#                 ('reg', Ridge(alpha=0.1, max_iter=50000, random_state=42))])

# %% [markdown]
# #### L1

# %% [markdown]
# Без масштабирования абсолютные значения коэффициентов отрисовала с логарифмическим масштабом, чтоб нагляднее было - там в десятки раз различия, на линейном масштабе не видно.

# %%
for alpha in ALPHAS:
    results = cross_validate(make_model(alpha=alpha, penalty='L1', is_scale=False),
                             X_hw, y_hw, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
        
    best_coeffs_indx = np.argmin([
        np.mean(np.abs(model['reg'].coef_))
        for model in results['estimator']
    ])

    plt.plot(np.fmax(np.abs(results['estimator'][best_coeffs_indx]['reg'].coef_), 1.0e-15))
    plt.xlabel('feature')
    plt.ylabel('weight')
    plt.yscale('log')
    plt.grid(True)
    plt.title('L1 without prescaling')

# %% [markdown]
# Здесь и в линейном норм - коэффициенты уменьшились

# %%
for alpha in ALPHAS:
    results = cross_validate(make_model(alpha=alpha, penalty='L1', is_scale=True),
                             X_hw, y_hw, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    
    best_coeffs_indx = np.argmin([
        np.mean(np.abs(model['reg'].coef_))
        for model in results['estimator']
    ])
    
    plt.plot(np.abs(results['estimator'][best_coeffs_indx]['reg'].coef_))
    plt.xlabel('feature')
    plt.ylabel('weight')
    plt.grid(True)
    plt.title('L1 with prescaling')

# %% [markdown]
# #### L2

# %%
for alpha in ALPHAS:
    results = cross_validate(make_model(alpha=alpha, penalty='L2', is_scale=False),
                             X_hw, y_hw, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    
    best_coeffs_indx = np.argmin([
        np.mean(np.abs(model['reg'].coef_))
        for model in results['estimator']
    ])
    
    plt.plot(np.fmax(np.abs(results['estimator'][best_coeffs_indx]['reg'].coef_), 1.0e-15))
    plt.xlabel('feature')
    plt.ylabel('weight')
    plt.yscale('log')
    plt.grid(True)
    plt.title('L2 without prescaling')

# %%
for alpha in ALPHAS:
    results = cross_validate(make_model(alpha=alpha, penalty='L2', is_scale=True),
                             X_hw, y_hw, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    
    best_coeffs_indx = np.argmin([
        np.mean(np.abs(model['reg'].coef_))
        for model in results['estimator']
    ])
    
    plt.plot(np.abs(results['estimator'][best_coeffs_indx]['reg'].coef_))
    plt.xlabel('feature')
    plt.ylabel('weight')
    plt.grid(True)
    plt.title('L2 with prescaling')

# %% [markdown]
# #### Summary

# %% [markdown]
# * Без масштабирования получаем и для L1 и для L2 сумасшедший разброс значений весов (для наглядности отобразила в логарифмическом масштабе, так как различия в десятки раз).
# * При использовании масштабирования значения коэффициентов становятся соизмеримыми (одного порядка). Для них графики в линейном масштабе
#
# Видим, что масштабирование очень важно для того, чтоб веса получались одного порядка.
#
# Кстати L1 без масштабирования несколько коэффициентов обратило в ноль. Характерное для L1 Поведение.
